# %% [markdown]
# # First notebook
#
# Getting comfortable with the Jupyter workflow.

# %%
import torch

print("PyTorch version:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
# Out:
# PyTorch version: 2.13.0
# MPS available: True

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
a + b
# Out:
# array([5, 7, 9])
